# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalpesh-Rajput/Capston-Project---EDA-Play-Store-App-Review-Analysis/blob/main/Kalpesh_Rajput_%7C_Play_Store_App_Review_Analysis_Capstone_Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CAPSTONE PROJECT**    : EXPLORATORY DATA ANALYSIS PLAY STORE APP REVIEW
# Name : Kalpesh Rajput
#
#
#
#
#
#
# Team/Individual : Individual
#
# ![google_play_logo.png](data:image/png;base64,...)

# %% [markdown]
# #The play store app data has enormous potential to drive app making business to success. Actionable insights can be drawn for developers to work on and capture the android market.Each app(row) has value for category,rating,size and more. Another dataset contains customer review of the android app.
#
# #explore and analyze the data to discover key factors responsible  for app engagement and success

# %% [markdown]
# # Introduction :
#
# In today's era the Google Play Store is the largest and most popular android app store. It is flooded with millions of application and it provides wide collection of data on features like rating,price, no of downloads  & app descriptons . Many app are being developed as apps are easy to create and its luctrative. But it is important for developers to know which apps are loved by customers and trending in market so that he develop only those apps and also there is high competion between app providers producting similar application.Analysing customer needs is one of the bizarre taks in the businesss world today. Hence proposing analyse data to developer that what customer is likely to download ,which category got the maximum download this all plays crucial role in app development.Generally, customers downloads apps depending on number of downloads , positive reviews ,negative reviews,rating and comments. In this projetc we have to above senarious and hepl developers to which kind of app people really like.

# %% [markdown]
# # Project Summary :
#
# *  Google Play store is an online store where people go to find their favourite  apps, games, movies, TV shows, books, and more. It provides 2 million apps & games to billions of people around the world
#
# *    Basically we have two data sets to Analise 1) play store data.csv &
# 2) User Review.csv
#
# *   we have to analyse our data and help our developers that they can enter in this market with their apps
#
# *    In this exploratory data analysis project we have look insight of the data and make sure that we get as much detailed to analyse  data.
# *   The main objective of this exploratory data analysis project is to recognize customer need and what kind of app they prefer most and help developers to popularize their app on play store that their app get famous.

# %% [markdown]
# # General Guidelines :

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # **Problem Statements :**

# %% [markdown]
# 1. What are the top categories on Play Store?
# 2. Which category App's have most number of installs?
# 3. What is percentage of Review Sentiments
# 4. Which category of Apps from the Content Rating column are found more on playstore ?
# 5. What portion of the apps in playstore are paid and free?
# 6. How does the count of apps varies by Genres?
# 7. What are the top 10 most reviewed App on Play Store app?
# 8. How are ratings affected when the app is a paid one?
# 9. Do price of the app effects the rating?
# 10. What is the distribution of type of reviews in the dataset?
# 11. What are the count of Apps in different genres?
# 12. Is there any relationship between Ratings vs Reviews. Does more number of reviews means more ratings?
# 13. How is sentiment polarity varying for paid and free apps?
# 14. Which are the top 10 expensive Apps in playstore?

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Kalpesh-Rajput/Capston-Project---EDA-Play-Store-App-Review-Analysis

# %% [markdown]
# # **Let's begin**

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
#  # This is formatted as code

# %%
# now let's start with importing the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data set loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
play_store_df = pd.read_csv('/content/drive/MyDrive/Play Store Data.csv')
user_review_df = pd.read_csv('/content/drive/MyDrive/User Reviews.csv')

# %% [markdown]
# # First view of our two datasets

# %%
# let's print our whole data and watch how it's looks like

play_store_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
user_review_df
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %% [markdown]
# # Let's count row and columns of dataset

# %%
 Columns_row = play_store_df.shape
 print('we have total ' , Columns_row , 'Columns and rows in play store data')
# Out:
# we have total  (10841, 13) Columns and rows in play store data

# %%
 Columns_row = user_review_df.shape
 print('we have total ' , Columns_row , 'Columns and rows in user review data')
# Out:
# we have total  (64295, 5) Columns and rows in user review data

# %% [markdown]
# # let's explore the two DataFrames

# %%
# Print the whole columns of both the DataFrame
print(play_store_df.columns)
print(user_review_df.columns)
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
play_store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
user_review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# # let's expplore play store data

# %%
# print first five rows of our first dataframe 'play_store_df' and see how it's look like
top_five_row_1= play_store_df.head(5)
top_five_row_1
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
rows = play_store_df.shape[0]
columns = play_store_df.shape[1]
print(f'there are {rows} and {columns} column are in our play store data set')
# Out:
# there are 10841 and 13 column are in our play store data set

# %%
play_store_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
play_store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
concat_data = pd.concat([play_store_df.head(10),play_store_df.tail(10)])
concat_data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10831                           payermonstationnement.fr  MAPS_AND_NAVIGATION
# ...

# %%
play_store_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# # We find below detail
#
# play store data has 10841 rows and 13 columns. Brief discription of these 13 columns as below
#
# 1) **App**           : It tells about name of application.
#
# 2) **Category**      : It tells about category to which application belongs.
#
# 3) **Rating**        : It tells about rating of applications given by users.
#
# 4) **Reviews**       : It tells about brief reviews about application given by users
#
# 5) **Size**          : It tells about the size of applications
#
# 6) Installs          : It tells about total number of installs/Downloads for an applications
#
# 7) **Type**          : It tells us whether the application is free or a paid one.
#
# 8) **Price**         : It tells us about the price of the application.
#
# 9) **Content_Rating**: It tells us about the target audience for the application.
#
# 10) **Genres**       : It tells us about the various other categories to which an application can belong.
#
# 11) **Last_Updated** : It tells us about the when the application was updated.
#
# 12) **Current_Ver**  : It tells us about the current version of the application.
#
# 13) **Android_Ver**  : It tells us about the android version which can support the application on its platform.

# %% [markdown]
# # Let's Explore User Review data

# %%
user_review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
# Lets print the first and last 10 rows of information of the dataframe.
concat_ur = pd.concat([user_review_df.head(10),user_review_df.tail(10)])
concat_ur
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# 5            10 Best Foods for You
# 6            10 Best Foods for You
# 7            10 Best Foods for You
# 8            10 Best Foods for You
# 9            10 Best Foods for You
# 64285  Houzz Interior Design Ideas
# 64286  Houzz Interior Design Ideas
# 64287  Houzz Interior Design Ideas
# 64288  Houzz Interior Design Ideas
# 64289  Houzz Interior Design Ideas
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# ...

# %%
# print first five rows of our seconds dataframe 'user_review_df' and see how it's look like
top_five_row_2 = user_review_df.head(5)
top_five_row_2
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
last_five_row = user_review_df.tail(5)
last_five_row
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %%
user_review_df.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %% [markdown]
# # We find below detail about our DataFrame
#
#
# user_reviews dataframe has 64295 rows and 5 columns. The 5 columns are identified as follows:
# 1. **App** - It tells  about the name of the application.
# 2. **Translated_Review** - It tells us about what the users feedback is about the application.
# 3. **Sentiment** - It tells us about a view or opinion of the user w.r.t. the application.
# 4. **Sentiment_Polarity** - Sentiment polarity for an element defines the orientation of the expressed sentiment, i.e., it determines if the text expresses the positive, negative or neutral sentiment of the user about the application.
# 5. **Sentiment_Subjectivity** - It refers to the text that contains text which is usually expressed by a human having typical moods, emotions, and feelings. Mostly it is a public opinion and not a factual information.

# %% [markdown]
# # In our data there are lots of duplicates and null values we have to deal with them & make data more comfortable.
#
# # To deal with dataframe we have to make copy of our original dataframe, and perform all actions in copied dataframe

# %%
# make copy of original datset
play_store  = play_store_df.copy()
user_review = user_review_df.copy()

# %%
# information about our play store dataset
play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# **In Play Store Dataset:**
# * Column **Rating** contains a lot of null values.
# * Other columns also contain null values, but they are less in numbers.

# %%
# information about our user review dataset
user_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# # Now we have to deal with duplicate values from play store dataset

# %%
# duplicate value count 

# generate function to get duplicate value count

def get_duplicate_value_count(df):
  duplicate_values = df[df.duplicated()]
  return print(f'there are {duplicate_values.count()} duplicate values are over here')

# %%
get_duplicate_value_count(play_store['App'])
# Out:
# there are 1181 duplicate values are over here

# %%
play_store[play_store['App']=='Quick PDF Scanner + OCR FREE']
# Out:
#                               App  Category  Rating Reviews  \
# 222  Quick PDF Scanner + OCR FREE  BUSINESS     4.2   80805
# 229  Quick PDF Scanner + OCR FREE  BUSINESS     4.2   80805
# 285  Quick PDF Scanner + OCR FREE  BUSINESS     4.2   80804
#
#                    Size    Installs  Type Price Content Rating    Genres  \
# 222  Varies with device  5,000,000+  Free     0       Everyone  Business
# 229  Varies with device  5,000,000+  Free     0       Everyone  Business
# 285  Varies with device  5,000,000+  Free     0       Everyone  Business
#
#           Last Updated         Current Ver   Android Ver
# 222  February 26, 2018  Varies with device  4.0.3 and up
# 229  February 26, 2018  Varies with device  4.0.3 and up
# 285  February 26, 2018  Varies with device  4.0.3 and up

# %% [markdown]
# *   We can observe that duplicate row contain exactly same detail.
# *   As we see duplicate values are not looks like good and we get error further so we have to drop these values in our dataset and we keep only those  values that occurs first.

# %%
play_store[play_store.duplicated()].count()
# Out:
# App               483
# Category          483
# Rating            474
# Reviews           483
# Size              483
# Installs          483
# Type              483
# Price             483
# Content Rating    483
# Genres            483
# Last Updated      483
# Current Ver       483
# Android Ver       483
# dtype: int64

# %% [markdown]
# *   As we can see there are duplicate value in each column we have to drop them

# %%
play_store.drop_duplicates(subset = 'App', keep = 'first' , inplace = True)

play_store.shape
# Out:
# (9660, 13)

# %%
# dealing with duplicate values

play_store[play_store.duplicated()].count()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# # Now we can say that we drop all the duplicate values in each column

# %% [markdown]
# # Now he have to see how many null values are there in our dataset

# %%
def PSinfo():
  PS = pd.DataFrame(index = play_store.columns)
  PS['data type'] = play_store.dtypes
  PS['Count of non null values']  = play_store.count()
  PS['NAN Values'] = play_store.isnull().count()
  PS['% of NAN Values'] = (PS['Null Values']/len(play_store)).round(4)*100
  PS['Unique count'] = play_store.nunique()
  return PS
PSinfo()

# %% [markdown]
# #Findings
#
# The number of null values are:
#
# 1) Rating has 1474 null values which contributes 13.60% of the data.
#
#
# 2) Type has 1 null value which contributes 0.01% of the data.
#
#
# 3) Content_Rating has 1 null value which contributes 0.01% of the data.
#
#
# 4) Current_Ver has 8 null values which contributes 0.07% of the data.
#
#
#
# 5) Android_Ver has 3 null values which contributes 0.03% of the data.

# %%
# we can se  here are lots of null values
print(play_store.App.nunique())
play_store.isnull()
# Out:
# 9660
#          App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0      False     False   False    False  False     False  False  False
# 1      False     False   False    False  False     False  False  False
# 2      False     False   False    False  False     False  False  False
# 3      False     False   False    False  False     False  False  False
# 4      False     False   False    False  False     False  False  False
# ...      ...       ...     ...      ...    ...       ...    ...    ...
# 10836  False     False   False    False  False     False  False  False
# 10837  False     False   False    False  False     False  False  False
# 10838  False     False    True    False  False     False  False  False
# 10839  False     False   False    False  False     False  False  False
# 10840  False     False   False    False  False     False  False  False
#
#        Content Rating  Genres  Last Updated  Current Ver  Android Ver
# ...

# %%
#  Let's Visualize null values 

import missingno as msno
msno.heatmap(play_store)
plt.show()

# %%
# As we can see there are lots of null values in rating column we have to look in to this.
play_store[~play_store['Rating'].isnull() == False ]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#       Reviews  Size  Installs  Type Price Content Rating  \
# ...

# %% [markdown]
# *   As discussed earlier we find that there are 1463 Null values in the column Rating of play_store. But it is also to get  noticed that even though values in Rating column is NaN/Null, these columns gives many other necessary insights about the apps like their category, size, number of installs, content rating ,  version and many other details.
# *   So we decided not to drop all the rows but rather than we have to replace these Null values with the mean rating of the dataset

# %%
# Now Let's define a function replaced null values

def replaced_null(df_name,value_need_to_replace):
  df_name.fillna(value = value_need_to_replace, inplace = True , axis = 0)
  return print(' we fill the null values with our desired values')

# %% [markdown]
# *   in above code we define to replace null values with our output
# *   Our above function has been define with two arguments

# %%
replaced_null(play_store['Rating'] , play_store['Rating'].mean())
# Out:
#  we fill the null values with our desired values

# %%
play_store.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# dtype: int64

# %% [markdown]
# * From above info we can see still there are some null values are present there before moving forward we have to deal with them and fixed it.
#   *  we can see only one null value is present in ***Type*** we replace it with off
#   * We will replace the single null value of 'Content Rating' column to 'Everyone'.
#   * after doing this we drop the columns

# %%
# Checking is there null value in type column.
play_store[~play_store['Type'].isnull() == False]
# Out:
#                             App Category    Rating Reviews  \
# 9148  Command & Conquer: Rivals   FAMILY  4.175052       0
#
#                     Size Installs Type Price Content Rating    Genres  \
# 9148  Varies with device        0  NaN     0   Everyone 10+  Strategy
#
#        Last Updated         Current Ver         Android Ver
# 9148  June 28, 2018  Varies with device  Varies with device

# %%
# Replacing null value with string 'Free'.
replaced_null(play_store['Type'],'Free')
# Out:
#  we fill the null values with our desired values

# %%
play_store.loc[9145:9150,:]
# Out:
#                                App Category    Rating  Reviews  \
# 9145  EA SPORTS™ FIFA 18 Companion   SPORTS  3.900000   282727
# 9146     The Simpsons™: Tapped Out   FAMILY  4.300000   636995
# 9147         Plants vs. Zombies™ 2   FAMILY  4.400000   567632
# 9148     Command & Conquer: Rivals   FAMILY  4.175052        0
# 9149  Star Wars™: Galaxy of Heroes   FAMILY  4.500000  1461698
# 9150                Dungeon Keeper   FAMILY  4.000000    69574
#
#                     Size     Installs  Type Price Content Rating  \
# 9145                 63M  10,000,000+  Free     0       Everyone
# 9146                 49M  10,000,000+  Free     0           Teen
# 9147                 15M  10,000,000+  Free     0   Everyone 10+
# 9148  Varies with device            0  Free     0   Everyone 10+
# 9149                 67M  10,000,000+  Free     0   Everyone 10+
# 9150                 45M     500,000+  Free     0   Everyone 10+
#
# ...

# %%
# Checking is there any null value in our Content 'Rating column'
play_store[~play_store['Content Rating'].isnull() == False]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# *   As we can see missing value of Category Column, all the next values have shifted one place to their left, hence messing up the whole coulmn. So we will drop this column

# %%
play_store.dropna(subset = ['Content Rating'] , inplace = True )
play_store.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %% [markdown]
# Still we have null values are available in Current ver and android ver but this two column not as much important as others we will replace the null values with last valid observation of our data set.

# %%
# Lets check the null values before trying to fill them in "Current Ver" column
play_store[~play_store['Current Ver'].isnull() == False]
# Out:
#                                    App             Category    Rating Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN  3.200000      55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO  4.100000   20145
# 6322            Virtual DJ Sound Mixer                TOOLS  4.200000    4010
# 6803                         BT Master               FAMILY  4.175052       0
# 7333                       Dots puzzle               FAMILY  4.000000     179
# 7407                   Calculate My IQ               FAMILY  4.175052      44
# 7730                            UFO-CQ                TOOLS  4.175052       1
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE  4.175052       8
#
#        Size    Installs  Type  Price Content Rating             Genres  \
# 15     2.7M      5,000+  Free      0       Everyone       Art & Design
# 1553    11k  1,000,000+  Free      0       Everyone   Libraries & Demo
# ...

# %%
# Using fill method we replace null values .

play_store['Current Ver'].fillna(value = None , method = 'ffill', axis = None , inplace = True)
play_store.loc[13:16,:]
# Out:
#                                                 App        Category  Rating  \
# 13                            Mandala Coloring Book  ART_AND_DESIGN     4.6
# 14  3D Color Pixel by Number - Sandbox Art Coloring  ART_AND_DESIGN     4.4
# 15                  Learn To Draw Kawaii Characters  ART_AND_DESIGN     3.2
# 16     Photo Designer - Write your name with shapes  ART_AND_DESIGN     4.7
#
#    Reviews  Size  Installs  Type Price Content Rating        Genres  \
# 13    4326   21M  100,000+  Free     0       Everyone  Art & Design
# 14    1518   37M  100,000+  Free     0       Everyone  Art & Design
# 15      55  2.7M    5,000+  Free     0       Everyone  Art & Design
# 16    3632  5.5M  500,000+  Free     0       Everyone  Art & Design
#
#       Last Updated Current Ver Android Ver
# 13   June 26, 2018       1.0.4  4.4 and up
# 14  August 3, 2018       1.2.3  2.3 and up
# 15    June 6, 2018       1.2.3  4.2 and up
# 16   July 31, 2018         3.1  4.1 and up

# %%
# We have to use same method to fill null values are avilable in Android Ver column
play_store['Android Ver'].fillna(value = None , method = 'ffill' , axis = None , inplace  = True)

# %%
play_store.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# Finally we deal with all the null values of our first dataset now we move forward to our second dataaset 'User Review Dataset'

# %% [markdown]
# #  User Review Dataset :

# %% [markdown]
# In user Review Dataset all the columns contain approx 26868 null values except App column

# %%
def URinfo():
  UR                          = pd.DataFrame(index = user_review.columns)
  UR['Data Type']             = user_review.dtypes
  UR['Count of non values']   = user_review.count()
  UR['NAN values']            = user_review.isnull().count()
  UR['% Of NAN Values']       = (UR['NAN values']/len(user_review)).round(4)*100
  UR['Unique Count']          = user_review.nunique()
  return URinfo()

URinfo

# %% [markdown]
#  # Findings
#
# The number of null values are:
#
# 1) Translated_Review has 26868 null values which contributes 41.79% of the data.
#
# 2) Sentiment has 26863 null values which contributes 41.78% of the data.
#
# 3) Sentiment_Polarity has 26863 null values which contributes 41.78% of the data.
#
# 4) Sentiment_Subjectivity has 26863 null values which contributes 41.78% of the data.

# %%
user_review.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
user_review[~user_review['Translated_Review'].isnull() == False]
# Out:
#                                App Translated_Review Sentiment  \
# 2            10 Best Foods for You               NaN       NaN
# 7            10 Best Foods for You               NaN       NaN
# 15           10 Best Foods for You               NaN       NaN
# 102          10 Best Foods for You               NaN       NaN
# 107          10 Best Foods for You               NaN       NaN
# ...                            ...               ...       ...
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 2                     NaN                     NaN
# 7                     NaN                     NaN
# 15                    NaN                     NaN
# ...

# %% [markdown]
# In above column all the values are null and it can't provide any valuable information so we have to drop column containing null values

# %%
user_review.dropna(subset = ['Translated_Review'] , inplace  = True)

# %%
user_review.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %% [markdown]
#  # Finally 😌
#
#
# Our both the data set are free from null values

# %%
# Lets see how our data looks like after removing duplicates and null vlues.
play_store
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# After looking at our data we need to reset index in our dataframe to get actual no of columns.

# %%
play_store.reset_index(inplace = True , drop = True)
play_store
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9654                                   Sya9a Maroc - FR               FAMILY
# 9655                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 9656                             Parkinson Exercices FR              MEDICAL
# 9657                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9658      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
user_review
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# ...

# %%
user_review.reset_index(inplace = True   , drop = True)
user_review
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 2               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# ...                               ...
# 37422  Housing-Real Estate & Property
# 37423  Housing-Real Estate & Property
# 37424  Housing-Real Estate & Property
# 37425  Housing-Real Estate & Property
# 37426  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2             Works great especially going grocery store  Positive
# 3                                           Best idea us  Positive
# 4                                               Best way  Positive
# ...                                                  ...       ...
# ...

# %% [markdown]
# #What are the things that we get from our dataset ?
#
#  Play Store Dataset :
#
#
#
# *   This dataset contain the details about all the applications present in the Google Play Store, like Name, Size, Category, number of installs etc. Google Play Store, like Name, Size, Category, number of installs etc.
#
# *   There are total 13 Columns and 10841 Rows in the Dataset.
#
# *   Duplicated Values :- In the column "App" 1181 Duplicated values were dropped and only those values were kept which occurred  first in dataframe.
#
#
# Duplicated Values :- In the column "App" 1181 Duplicated values were dropped and only those values were kept which occurred  first in dataframe.
#
# Null Values :-
#
#
#
# 1. Rating Column had 1463 Null Values, replaced with mean rating.
# 2. Type Column has 1 Null Value, replaced with str 'Free'
# 3. Content Rating Column had 1 Null Value, but after looking at data it was realised that data was messed up hence we dropped it.
# 4. Columns "Current Ver" and "Android Ver" has combined 10 Null Values, we replaced them with last valid observations as this step will not hamper our EDA.
#
#
# After cleaning the data, we had the indexes reset and now the remaining number or rows are 9659 in our play_store_df.
#
# ###   ***User Review Dataset i.e user_Review_df:***
#
#   * This dataset contain the details about all the reviews given by users after instaling and using applications from Google Playstore.
#
#   * This dataset also contains sentiment (Positive, Neutral or Negative) about the reviews
#
#   * There were total 5 Columns and 64295 Rows in the Dataset.
#
#   * **Duplicated Values** :- In the column "App" we found 33616 duplicated values, but because this dataframe may contain several reviews for a single app hence we refrain from deleting data from this dataset from now.
#
#   * **Null Values** All the columns except the "App" column contained exactly (almost exactly) 26868 Null Values. On visualizing it was found that, except the app name, all other columns were containing Null values in these rows, hence we dropped all these rows.
#
#   * After cleaning the dataset, we had rest the Index and ***now there are 37427 number of rows in the user_review_df***.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Play Store Dataset Columns
play_store.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# **Findings**
#
# play_store dataframe has 10841 rows and 13 columns. The 13 columns are identified as below:
#
# 1. **App** - It tells us about the name of the application.
# 2. **Category** - It tells us about the category to which an application belongs.
# 3. **Rating** - It tells us about the ratings given by the users for a specific application.
# 4. **Reviews** - It tells us about the total number of users who have given a review for the application.
# 5. **Size** - It tells us about the size being occupied the application on the mobile phone.
# 6. **Installs** - It tells us about the total number of installs/downloads for an application.
# 7. **Type** - It tells us whether the application is free or a paid one.
# 8. **Price** - It tells us about the price of the application.
# 9. **Content_Rating** - It tells us about the target audience for the application.
# 10. **Genres** - It tells us about the various other categories to which an application can belong.
# 11. **Last_Updated** - It tells us about the when the application was updated.
# 12. **Current_Ver** - It tells us about the current version of the application.
# 13.**Android_Ver** - It tells us about the android version which can support the application on its platform.

# %%
# User Review Dataset Columns
user_review_df.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %% [markdown]
# **Findings**
#
# user_reviews dataframe has 64295 rows and 5 columns. The 5 columns are identified as follows:
# 1. **App** - It tells us about the name of the application.
# 2. **Translated_Review** - It tells us about what the users feedback is about the application.
# 3. **Sentiment** - It tells us about a view or opinion of the user w.r.t. the application.
# 4. **Sentiment_Polarity** - Sentiment polarity for an element defines the orientation of the expressed sentiment, i.e., it determines if the text expresses the positive, negative or neutral sentiment of the user about the application.
# 5. **Sentiment_Subjectivity** - It refers to the text that contains text which is usually expressed by a human having typical moods, emotions, and feelings. Mostly it is a public opinion and not a factual information.

# %%
# Verifying whether data type of all columns are right
play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          9659 non-null   float64
#  3   Reviews         9659 non-null   object
#  4   Size            9659 non-null   object
#  5   Installs        9659 non-null   object
#  6   Type            9659 non-null   object
#  7   Price           9659 non-null   object
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9659 non-null   object
#  12  Android Ver     9659 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 981.1+ KB

# %% [markdown]
# ## In the Play Store Data there are some flaws in the data types of columns, like:
# * Data in "Rating" & "Size" columns are showing to be object Dtype whereas actually they should be Float.
#
# * Data in "Reviews" and "Installs" columns are also object Dtype whereas it should be Integer(Int) Type.
#
# * Converting columns "Rating" and "Reviews" is easy but, not so easy in Columns "Size" and "Installs".
#
# * In column "Size" we will convert all sizes to a single unit i.e. Mb and the we will remove the string part "M" from the values.
#
# * In "Installs" column we will remove the "+" object from the number and only keep the numebers as the values.
#
# ### Lets convert these columns to correct Data Types so that we can start with our data analysis and visualisation.

# %%
# Need to define a function to clean the 'Size' column in our dataset
def clean_size (df):
  for i in df['Size']:
    try:
      df['Size'] = df['Size'].apply(lambda x : x.replace('M' , '') if 'M' in str(x) else x)
      df['Size'] = df['Size'].apply(lambda x : round(float(x.replace('k',''))/1024,2) if 'k' in str(x) else x)
      df["Size"] = df["Size"].apply(lambda x : x.replace('Varies with device', '0') if 'Varies with device' in str(x) else x)
    except :
      pass
    finally:
      df['Size'] = pd.to_numeric(df['Size'])  
      df.rename(columns={'Size': 'Size(in MB)'}, inplace= True)    
    return df

# %%
# We also define a function to 'Installs' column from our dataset & we replace '+'  with null value so that we are left with only numeric values.

def clean_install(df):
  for i in df['Installs']:
    try:
      df['Installs'] = df['Installs'].apply(lambda x : x.replace('+' , '') if '+' in str(x) else x)
      df['Installs'] = df['Installs'].apply(lambda x : x.replace(',' , '') if ',' in str(x) else x)
    except:
      pass
    finally:
      df['Installs']  = pd.to_numeric(df['Installs'])

    return df

# %%
# Let's apply our function and see whether it is working properly
clean_size(play_store)
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9654                                   Sya9a Maroc - FR               FAMILY
# 9655                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 9656                             Parkinson Exercices FR              MEDICAL
# 9657                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9658      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# *   We can see that our "clean_size" function worked properly and  converted all the sizes into a single unit of Mb and also change the column name from "Size" to "Size (in Mb)"

# %%
# Now let's apply our 2nd function to clean the column "installs" and see whether it is working correctly
clean_install(play_store)
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9654                                   Sya9a Maroc - FR               FAMILY
# 9655                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 9656                             Parkinson Exercices FR              MEDICAL
# 9657                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9658      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# * We can see that our 2nd function "clean_install" function has worked properly and removed "+" sign from the number of installs

# %%
# Converting the column "Reviews" from Dtype Object to Numeric

play_store['Reviews'] = pd.to_numeric(play_store['Reviews'])

# %%
play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          9659 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size(in MB)     9659 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9659 non-null   object
#  7   Price           9659 non-null   object
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9659 non-null   object
#  12  Android Ver     9657 non-null   object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 981.1+ KB

# %%
play_store.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size(in MB)', 'Installs',
#        'Type', 'Price(in $USD)', 'Content Rating', 'Genres'],
#       dtype='object')

# %%
# In our dataset column Price should have a numeric dtype but due to presence of '$' sign its shows dtype object

play_store['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
# Lets fix this issue and convert Dtype of column "Price" from Object to Numeric by defining a fucntion for removing the "$" sign from the values

def clean_price_column (df):
  for i in df['Price']:
    try:
      df['Price'] = df['Price'].apply (lambda x: x.replace('$','') if '$' in x else x)
    
    except:
      pass
    
    finally:
      df['Price'] = round(pd.to_numeric((df['Price'])),2)  
      df.rename(columns={'Price': 'Price(in $USD)'}, inplace= True)
    
    return df

# %%
# Let's apply the fucntion and check whether it  worked as per our requirement or not
clean_price_column(play_store)
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9654                                   Sya9a Maroc - FR               FAMILY
# 9655                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 9656                             Parkinson Exercices FR              MEDICAL
# 9657                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9658      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# now we can see in our dataset price column contain only numeric values and we
# chnage $ sign
# chnage '$' sign and also chnage column name price to Price(in $USD)

# %%
# Lets check dtype of column 'Price' after cleaning this
play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          9659 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size(in MB)     9659 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9659 non-null   object
#  7   Price(in $USD)  9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9659 non-null   object
#  12  Android Ver     9657 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 981.1+ KB

# %% [markdown]
# * Hence we can see that Data type of all the numeric columns have now been  changed to either int64 or float64 which are both numeric entities.

# %%
# lets describe our dataset
play_store.describe()
# Out:
#             Rating       Reviews  Size(in MB)      Installs  Price(in $USD)
# count  9659.000000  9.659000e+03  9659.000000  9.659000e+03     9659.000000
# mean      4.173517  2.165926e+05    17.804105  7.777507e+06        1.099299
# std       0.494313  1.831320e+06    21.495511  5.375828e+07       16.852152
# min       1.000000  0.000000e+00     0.000000  0.000000e+00        0.000000
# 25%       4.000000  2.500000e+01     2.900000  1.000000e+03        0.000000
# 50%       4.200000  9.670000e+02     9.100000  1.000000e+05        0.000000
# 75%       4.500000  2.940100e+04    25.000000  1.000000e+06        0.000000
# max       5.000000  7.815831e+07   100.000000  1.000000e+09      400.000000

# %%
# lets describe our second dataset
user_review.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# #Now lets check Unique values in our *columns*

# %%
# lets define a function to get unique values from dataset

def get_uniques(df):
  for i in df.columns:
    print(f"There are {df[i].nunique()} unique value in our column '{i}' " )

# %%
# let's get overview of our dataset play_store that contain unique values in each column
get_uniques(play_store)
# Out:
# There are 9659 unique value in our column 'App'
# There are 33 unique value in our column 'Category'
# There are 40 unique value in our column 'Rating'
# There are 5330 unique value in our column 'Reviews'
# There are 274 unique value in our column 'Size(in MB)'
# There are 20 unique value in our column 'Installs'
# There are 2 unique value in our column 'Type'
# There are 92 unique value in our column 'Price(in $USD)'
# There are 6 unique value in our column 'Content Rating'
# There are 118 unique value in our column 'Genres'
# There are 1377 unique value in our column 'Last Updated'
# There are 2817 unique value in our column 'Current Ver'
# There are 33 unique value in our column 'Android Ver'

# %%
# let's get overview of our dataset user_revew that contain unique values in each column
get_uniques(user_review)
# Out:
# There are 865 unique value in our column 'App'
# There are 27994 unique value in our column 'Translated_Review'
# There are 3 unique value in our column 'Sentiment'
# There are 5410 unique value in our column 'Sentiment_Polarity'
# There are 4474 unique value in our column 'Sentiment_Subjectivity'

# %% [markdown]
# ## 3. ***DATA WRANGLING***

# %% [markdown]
# Let's do some Wrangling on our data

# %% [markdown]
# * After looking at the coulmns it seems that there are 3 columns which we can drop without sacrificing any important data in order to achieve our objective, these are:
#   * Last Updated
#   * Current Ver
#   * Android Ver
#
# * So, next we will drop these columns from our dataset and finally our dataset will be ready for the data wrangling and data visualization.

# %%
# Lets drop unwanted columns 
play_store.drop(columns = ['Current Ver', 'Android Ver'], inplace= True)

# %%
# Now we can see unwanted coulumns are sucessfully dropped from our dataset that our dataset looks good and more readable
play_store
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9654                                   Sya9a Maroc - FR               FAMILY
# 9655                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 9656                             Parkinson Exercices FR              MEDICAL
# 9657                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9658      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# * ### We have successfully processed the values and corrected the data type according to our need.

# %% [markdown]
# * ### Now that we have both of our datasets ready for data wrangling and visualization, we will go one step further and create a third dataframe.
#
# * ### We will name the third dataframe as "combine_df". In this combine_df we will merge the existing two datasets on the basis of "App" names to get a single dataset where both "App" and "User Review" data is present.

# %%
# Creating combine dataset
combine_df = pd.merge(play_store,user_review,how = 'inner' , left_on = 'App' , right_on = 'App')

# %%
# Getting info of our dataset
combine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35929 entries, 0 to 35928
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     35929 non-null  object
#  1   Category                35929 non-null  object
#  2   Rating                  35929 non-null  float64
#  3   Reviews                 35929 non-null  int64
#  4   Size(in MB)             35929 non-null  float64
#  5   Installs                35929 non-null  int64
#  6   Type                    35929 non-null  object
#  7   Price(in $USD)          35929 non-null  float64
#  8   Content Rating          35929 non-null  object
#  9   Genres                  35929 non-null  object
#  10  Last Updated            35929 non-null  object
#  11  Translated_Review       35929 non-null  object
#  12  Sentiment               35929 non-null  object
#  13  Sentiment_Polarity      35929 non-null  float64
# ...

# %% [markdown]
# we can see there are no null values in our combine dataset

# %%
# Let's use get_duplicate_value_count function to find whether our combine_df contain any duplicate row or column
get_duplicate_value_count(combine_df)
# Out:
# there are App                       7679
# Category                  7679
# Rating                    7679
# Reviews                   7679
# Size(in MB)               7679
# Installs                  7679
# Type                      7679
# Price(in $USD)            7679
# Content Rating            7679
# Genres                    7679
# Last Updated              7679
# Translated_Review         7679
# Sentiment                 7679
# Sentiment_Polarity        7679
# Sentiment_Subjectivity    7679
# dtype: int64 duplicate values are over here

# %% [markdown]
# shitttttttttt.... Its Quit interesting, still we have 7679 duplicates in our dataset????
#
# Lets use python defined function to figure out  the duplicated values in our dataset

# %%
# Checking the duplicates values in our dataset
combine_df[combine_df.duplicated() == True]
# Out:
#                                 App             Category  Rating  Reviews  \
# 19              Coloring book moana       ART_AND_DESIGN     3.9      967
# 20              Coloring book moana       ART_AND_DESIGN     3.9      967
# 22              Coloring book moana       ART_AND_DESIGN     3.9      967
# 23              Coloring book moana       ART_AND_DESIGN     3.9      967
# 24              Coloring book moana       ART_AND_DESIGN     3.9      967
# ...                             ...                  ...     ...      ...
# 34699  Comptia A+ 220-901 & 220-902               FAMILY     4.4      174
# 34700  Comptia A+ 220-901 & 220-902               FAMILY     4.4      174
# 34791                          Azar        COMMUNICATION     4.2  1092337
# 34792                          Azar        COMMUNICATION     4.2  1092337
# 35298                         Bible  BOOKS_AND_REFERENCE     4.7  2440695
#
#        Size(in MB)   Installs  Type  Price(in $USD) Content Rating  \
# ...

# %%
# lets check translated review column
combine_df[combine_df['Translated_Review'] == 'It bad >:(']
# Out:
#                     App        Category  Rating  Reviews  Size(in MB)  \
# 1   Coloring book moana  ART_AND_DESIGN     3.9      967         14.0
# 24  Coloring book moana  ART_AND_DESIGN     3.9      967         14.0
#
#     Installs  Type  Price(in $USD) Content Rating                     Genres  \
# 1     500000  Free             0.0       Everyone  Art & Design;Pretend Play
# 24    500000  Free             0.0       Everyone  Art & Design;Pretend Play
#
#         Last Updated Translated_Review Sentiment  Sentiment_Polarity  \
# 1   January 15, 2018        It bad >:(  Negative              -0.725
# 24  January 15, 2018        It bad >:(  Negative              -0.725
#
#     Sentiment_Subjectivity
# 1                 0.833333
# 24                0.833333

# %% [markdown]
# * In our combine_df there are lots of  diuplicate rows which contains exactly the same data. After being satisfied that these rows are indeed duplicates, we will remove the duplicated rows.

# %%
# lets get rid from duplicate values in our new combine dataset
combine_df.drop_duplicates(keep='first', inplace=True)

# %%
# We remove all the duplicates from our dataset
combine_df.duplicated().sum()
# Out:
# 0

# %%
# Getting the unique values of combined_df
get_uniques(combine_df)
# Out:
# There are 816 unique value in our column 'App'
# There are 33 unique value in our column 'Category'
# There are 22 unique value in our column 'Rating'
# There are 807 unique value in our column 'Reviews'
# There are 167 unique value in our column 'Size(in MB)'
# There are 12 unique value in our column 'Installs'
# There are 2 unique value in our column 'Type'
# There are 9 unique value in our column 'Price(in $USD)'
# There are 5 unique value in our column 'Content Rating'
# There are 67 unique value in our column 'Genres'
# There are 247 unique value in our column 'Last Updated'
# There are 26682 unique value in our column 'Translated_Review'
# There are 3 unique value in our column 'Sentiment'
# There are 5295 unique value in our column 'Sentiment_Polarity'
# There are 4382 unique value in our column 'Sentiment_Subjectivity'

# %% [markdown]
# * We can see that in the new combine_df there is data belonging to only 816 unique Apps.
#
# * It means that only 816 applications's matching data is present in **user_review_df** out of 9659 apps in **play_store_df** .

# %%
# Now lets finf total installs of apps listed in Google Play Store worldwide?

play_store['Installs'].sum()
# Out:
# 75122937527

# %% [markdown]
# *  The applications listed in Google Play Store have been installed a whopping 75.122 Billion times altogether, which is almost 10 times the the world population itself.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1. We have joined the two datasets using "Inner Join" on the column "App" in order to create a new joined dataset and have named it combined_df.
# 2. After obtaining the combined dataset, we checked it for duplicated values.
# 3. We found that there were 7679 duplicated entries present in the combined dataset, we have double checked the duplicate entries and found that they contain exactly the same details in every column.
# 4. We removed the duplicated values and kept only the first occurrence  of each duplicate row.

# %% [markdown]
# ## ***4. Data Vizualization,Problem Statements, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ## ***1. Top categories on Google Playstore?***

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['figure.figsize'] = (9,5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
play_store.groupby("Category")["App"].count().sort_values(ascending = False)
# Out:
# Category
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %%
y = play_store['Category'].value_counts().index
x = play_store['Category'].value_counts()
xaxis = []
yaxis = []

for i in range(len(x)):
  xaxis.append(x[i])
  yaxis.append(y[i])

# %%
plt.figure(figsize = (15,11))
plt.xlabel('Count')
plt.ylabel("Categories")
graph = sns.barplot(x = xaxis , y = yaxis , palette = 'husl')
graph.set_title('Top Categories on Playstore App' , fontsize = 20);

# %%
##Basic pie chart to view distribution of apps across various categories

fig,ax = plt.subplots(figsize = (10,10) , subplot_kw = dict(aspect = 'equal'))
number_of_app = play_store['Category'].value_counts()
labels = number_of_app.index
sizes = number_of_app.values
ax.pie(sizes,labeldistance=2,autopct = '%1.1f%%')
ax.legend(labels=labels,loc = "right",bbox_to_anchor=(0.9,0,0.5,1))
ax.axis('equal')
plt.show()

# %%
plt.figure(figsize = (15,5))
ax =sns.countplot(x='Category' , data = play_store , palette = 'Set1' , order = play_store['Category'].value_counts().index)
plt.ylabel('Number of apps')
plt.title('Number of app per category', fontsize = 20)

for item in ax.get_xticklabels():
  item.set_rotation(90)

# %% [markdown]
# **Findings:**
#
# So there are all total 33 categories in the dataset From the above output we can come to a conclusion that in playstore **most** of the apps are under **FAMILY** & **GAME** category and **least** are of **EVENTS** & **BEAUTY** Category.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# ---
# * I picked this chart to see the top categories in terms of number of apps in Google Play Store.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# ---
# * In the above figure we can see that the most number of apps present in Play Store App belongs to category "Family"

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.
# ---
# * The above chart can be used to make an informed decision to target a category, which is popular among user and not having a lot of apps listed in Google Playstore.

# %% [markdown]
# ### ***2. Which category App's have most number of installs?***

# %%
# We have to groupby category and installs to find which app has most number of installs
highest_installs_app = play_store.groupby('Category')[['Installs']].sum().sort_values(by = 'Installs' ,ascending = False)

# %%
x2axis = []
y2axis = []

for i in  range(len(highest_installs_app)):
  x2axis.append(highest_installs_app.Installs[i])
  y2axis.append(highest_installs_app.index[i])

plt.figure(figsize = (18,13))
plt.xlabel('Installs')
plt.ylabel('Category')

graph = sns.barplot(x = x2axis , y = y2axis , alpha = 0.9 , palette = 'viridis')
graph.set_title('Most Installs app on playstore' , fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Most Installs app on playstore')

# %% [markdown]
# **Findings:**
#
# From the above visualization, it can be interpreted that the top categories with **highest** installs are **Game, Communication,Family,Tools, Productivity.**

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * In the chart we see which are the categories where most number of apps are present in Playstore. but in this chart we have plotted categories in terms of number of installs, so as to see the categories which are most popular among users.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The top 3 most popular categories among users are Game, Communication & Productivity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# * If we compare chart the charts we can see that although the most number of apps present in playstore belongs to categories like Family, Game, Tool, Business, Medical. However, the most installed apps belong to categories like Game, Communication, Tools, Productivity &, Social.
# * Hence we can see that categories where comparatively less number of app are present but they are more popular among users (categories like Communication & Social) can be targeted for future business expansion purpose.

# %% [markdown]
# # ***3. Percentage of Review Sentiments*** **bold text**

# %%
counts = list(combine_df['Sentiment'].value_counts())
labels = 'Positive Reviews', 'Negative Reviews','Neutral Reviews'
matplotlib.rcParams['font.size'] = 12
matplotlib.rcParams['figure.figsize'] = (8, 8)
plt.pie(counts, labels=labels, explode=[0, 0.05, 0.005], shadow=True, autopct="%.2f%%")
plt.title('A Pie Chart Representing Percentage of Review Sentiments', fontsize=20)
plt.axis('off')
plt.legend()
plt.show()

# %% [markdown]
# **Findings:**
# 1. Positive reviews are **64.21%**
# 2. Negative reviews are **21.44%**
# 3. Neutral reviews are **14.35%**

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I picked this chart to check theSentiment Polarity Distribution of user reviews

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Approx **64.30%** are Positive reviews
# 2. Approx **22.80%** are Positive reviews
# 3. Approx **12.90%**are Positive reviews

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * We can say that most of the users are happy with the quality and Content of the Apps, considering the fact there are 64.30% review are positive.

# %% [markdown]
# ## ***4. Which category of Apps from the Content Rating column are found more on playstore ?***

# %%
k1 = play_store['Content Rating'].value_counts().index
k2 = play_store['Content Rating'].value_counts()

k1axis = []
k2axis = []


for i in range (len(k2)):
  k1axis.append(k1[i])
  k2axis.append(k2[i])

# %%
plt.figure(figsize = (10,5))
plt.bar(k1axis,k2axis,width=0.4,color=['#15244C','#FFFF48','#292734','#EF2920','#CD202D','#ECC5F2'], alpha=0.8)
plt.title('Content Rating' , size = 20)
plt.xlabel('Content Rating')
plt.ylabel('App(count)')
# Out:
# Text(0, 0.5, 'App(count)')

# %% [markdown]
# **Findings:**
#
# From the above plot we can see that **Everyone** category has the **highest** number of apps.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# By this chart we easily find comparision in different content rating.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above chart we get better understanding that most number of app  are from ***everyone*** category  then after  ***teens*** are most no of app.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From above chart we get insight to hepl creating a positive business impact.
#
# From the above plot we can see that **Everyone** category has the **highest** number of apps.

# %% [markdown]
# ## ***5. What portion of the apps in playstore are paid and free?***

# %%
paid_vs_free = play_store['Type'].value_counts().reset_index()
paid_vs_free.rename(columns = {'index': 'Type' , 'Type':'number'} , inplace = True)
paid_vs_free
# Out:
#    Type  number
# 0  Free    8903
# 1  Paid     756

# %%
plt.figure(figsize=(8,10))
plt.pie(x = 'number' , data = paid_vs_free , labels = 'Type', shadow=True, autopct='%.0f%%' )
plt.title('Paid App Vs Free App' , fontsize = 15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# ---
# * I picked this chart to see the comparison between the number of Free and Paid apps present in Play Store.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# ---
# * After viewing this pie chart we were able to see that only 8% out of total apps in Google Play Store are paid apps, and rest 92% are free to use.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.
# ---
# * This information will help business to decide whether they should keep the app free to install and generate revenue from ads and other subscriptions OR should it be a paid app.

# %% [markdown]
# ## ***6. What are the top 10 most reviewed App on Play Store app?***

# %%
top_10_review_app = play_store.sort_values(by = ['Reviews'] , ascending = False).head(10).reset_index(drop = True)

sns.barplot(y = 'App', x = 'Reviews' , data = top_10_review_app , palette  = 'rainbow' , orient = 'h')
plt.title('Top 10 Most Review app')
plt.xlabel('name of apps')
plt.ylabel('number of Installs')
# Out:
# Text(0.5, 1.0, 'Top 10 Most Review app')

# %%
top_10_reviewed_apps
# Out:
#                                                  App       Category  Rating  \
# 0                                           Facebook         SOCIAL     4.1
# 1                                 WhatsApp Messenger  COMMUNICATION     4.4
# 2                                          Instagram         SOCIAL     4.5
# 3           Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 4                                     Clash of Clans           GAME     4.6
# 5            Clean Master- Space Cleaner & Antivirus          TOOLS     4.7
# 6                                     Subway Surfers           GAME     4.5
# 7                                            YouTube  VIDEO_PLAYERS     4.3
# 8  Security Master - Antivirus, VPN, AppLock, Boo...          TOOLS     4.7
# 9                                       Clash Royale           GAME     4.6
#
#     Reviews  Size(in MB)    Installs  Type Price Content Rating  \
# 0  78158306          0.0  1000000000  Free     0           Teen
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * This chart was picked to see the Apps with most number of reviews in order to get an estimate of their popularity among people

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The most reviewed apps belong to Game, Social, Communication etc categories

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# One important insight that we can see from this chart that there are 3 Apps in the top 10 which are targeted towrds Teens as their audience.
# * From Chart no. 5 we can see that there are total 1036 apps targeted towards Teens as audience, which is much lesser in number if we see "Everyone" category having 7903 Apps, yet 3 of them featured in top 10 reviewed apps.
# * This means there is a lot of potential to grow the business if we can appropriately target Teens as our audience.

# %% [markdown]
# # ***7. Histogram of Subjectivity***

# %%
combine_df.Sentiment_Subjectivity.value_counts()
# Out:
# 0.000000    3488
# 1.000000    1358
# 0.500000    1282
# 0.600000     940
# 0.750000     888
#             ...
# 0.454870       1
# 0.621296       1
# 0.582630       1
# 0.402083       1
# 0.545714       1
# Name: Sentiment_Subjectivity, Length: 4382, dtype: int64

# %%
plt.figure(figsize = (18,9))
plt.xlabel('Subjectivity')
plt.ylabel('Distibution of Subjectivity')
plt.title('Histogram of Subjectivity')
plt.hist(combine_df[combine_df['Sentiment_Subjectivity'].notnull()]['Sentiment_Subjectivity'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
#
#
# *   I pick this chart to check where the sentiment of subjectivity lies

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
#
#
# *  **0 - objective(fact)**
# *   **1 - subjective(opinion)**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It can be seen that maximum number of sentiment subjectivity lies between 0.4 to 0.7. From this we can conclude that maximum number of users give reviews to the applications, according to their experience.

# %% [markdown]
# # ***8. Do price of the app effects the rating?***

# %%
fig,ax= plt.subplots(figsize = (14,8))
sns.regplot(x = "Price(in $USD)" , y = "Rating" , data = play_store)
plt.title("Prive VS Rating" ,size = 20)
# Out:
# Text(0.5, 1.0, 'Prive VS Rating')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# I pick this chart to know about the price of any app does effect on its rating.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that as the Price increasing the ratings recived seems to decrease even below the average rating  in playstore app.

# %% [markdown]
# #***9. It would be interesting to see if there is any relationship between Ratings vs Reviews. Does more number of reviews means more ratings?***

# %%
k = sns.lmplot(x = 'Reviews' , y = 'Rating' , data = play_store)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We prefer this chart to find is there any relationship between Rating and Review, does the more number of review mean more rating

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   From the above plot, we cannot say that there is a relation, it seems that irrespective of the Reviews, the ratings are majorly between 4 and 5, which we also noticed before.
#
# *   Also it is not correct to assume that rating and reviews have a relationship because reviews can be positive or negative and increase in the number of reviews does not show whether.  the Reviews are Positive or Negative.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Yes we get insights to help creating a positive business impact.
#
#
# *   From the above plot, we cannot say that there is a relation, it seems that irrespective of the Reviews, the ratings are majorly between 4 and 5, which we also noticed before.

# %% [markdown]
# # ***10. What is the distribution of type of reviews in the dataset?***

# %%
category_sentiment = combine_df.groupby(['Category','Sentiment']).size().reset_index(name='Sentiment Count')
category_sentiment['log_sentiment_count'] = np.log2(category_sentiment['Sentiment Count'])
plt.figure(figsize=(15,5))
plt.xticks(rotation=90,fontsize=11)
plt.xlabel("Category", fontsize=15)
plt.ylabel("Installs", fontsize=15)
plt.title("Number of installs type wise according to Genres",fontsize=15)
sns.barplot(x="Category", y="log_sentiment_count", hue="Sentiment", data=category_sentiment)
# Out:
# <Axes: title={'center': 'Number of installs type wise according to Genres'}, xlabel='Category', ylabel='log_sentiment_count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We pick this chart to find sentiment of category of app listed i playstore.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Majority of the genres have high positive sentiments, when compared to neutral and negative ones.

# %% [markdown]
# # ***11. Let us try to understand and co-relate rating, reviews and price columns together.***

# %%
f,(ax1,ax2,ax3) = plt.subplots(ncols = 3 , sharey = False)
sns.boxplot(x = 'Rating' , data = play_store , ax = ax1)
sns.boxplot(x = 'Reviews', data = play_store , ax = ax2)
sns.boxplot(x = 'Price(in $USD)' , data = play_store , ax = ax3)
f.set_size_inches (15,5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I pick this chart to visualize co-relate between Review,Rating and price.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.   We can see that most of the Ratings are between 4 and around  4.5 and 5
#
# 2.   As far as review are connected , for most of the Apps Review are not given.
#
# 3.   Also Price most of the Apps are free.

# %% [markdown]
# # ***12. Let us get some insight about the ratings for each category***

# %%
f , ax1 = plt.subplots(ncols = 1)
sns.boxplot(x = 'Category' ,  y = 'Rating' , data = play_store)
plt.xticks(rotation = 90)  # it is use for rotate your x column.
f.set_size_inches(15,5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I pick this chart to get know about Ratings of each Category

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this chart we get know about most of the ratings are between 4 to 4.5 and 5.

# %% [markdown]
# # ***13.What are the count of Apps in different genres?***

# %%
topgens = play_store['Genres'].value_counts().head(40)

# %%
x3sis = []
y3sis = []

for i in range (len(topgens)):
  x3sis.append(topgens.index[i])
  y3sis.append(topgens[i])

# %%
plt.figure(figsize = (15,9))
plt.xlabel('Genres(counts')
plt.ylabel('Genres')
graph = sns.barplot(x = x3sis , y = y3sis , palette = "deep")
graph.set_xticklabels(graph.get_xticklabels() , rotation = 90 , fontsize = 12)
graph.set_title("Top Genres of Play Store" , fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Top Genres of Play Store')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I pick this chart to visualize Top genres on Play Store App

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above visualization we can see that the Highest Number of Apps found in the **Tools and Entertainment genres followed by Education, Productivity, Finance** and many more.

# %% [markdown]
# ## ***14. Distribution of the ratings of the apps?***

# %%
plt.figure(figsize = (13,5))
plt.xlabel("Rating")
plt.ylabel("Frequency")
graph = sns.kdeplot(play_store.Rating , color = 'Blue' , fill = True)
plt.title('Distribution of rating')
# Out:
# Text(0.5, 1.0, 'Distribution of rating')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I pick this chart to visualize the top ratings on Play tore

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above graph we can come to a conclusion that most of the apps in google playstore are rated in between **3.5 to 4.8**

# %% [markdown]
# ## ***15. Which are the top 10 expensive Apps in playstore?***

# %%
top10apps = play_store[play_store['Type'] == 'Paid'].sort_values(by = 'Price(in $USD)' , ascending = False).head(11)

# %%
plt.figure(figsize = (20,12))
plt.pie(top10apps.Installs , explode = None , labels = top10apps.App , autopct = '%1.1f%%' , startangle = 0)
plt.title('Top 10 Expensive App Distribution' , size = 20)
plt.legend(top10apps.App,
           loc = 'lower right',
           title = 'Apps',
           fontsize = "xx-small"
           )

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I pick this chart to find which are the top 10 most expensive apps on Google Play store

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above graph we can interprete that the **I am Rich** app is the **most expensive app** in the play_store. But this seems to be like a junk app. We need to further analyze if it is a junk app or not by deploying machine learning models in it.

# %% [markdown]
# ## ***16. Pair Plot***

# %%
sns.pairplot(combine_df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# pairplot is used to quickly visualize correltions between variables using scatterplots and comparing all the columns of a dataste with each other in a single go

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We are unable to find a pattern for correlation, which means there is no need to make further changes to columns in order to treat any strong correlation in data

# %% [markdown]
# ## ***17. Ploting Heatmap For combine dataset***

# %%
plt.figure(figsize=(16,8))
corr= combine_df.corr()
sns.heatmap(corr)
plt.show()
# Out:
# <ipython-input-125-e414853a88d2>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr= combine_df.corr()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I picked this chart to quickly visualize if there is any Correlation between
# the variables (Columns) of our dataset

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * There seems a little relation between number of Installs and number of Reviews of an App, which we saw in previous charts that as an App becomes popular and more number of people install it, the number or reviews also increases for that app.
# * Other than this, there seems no important correlation between different variables of our dataset.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
#  ***1. Top categories on Google Playstore?***
# * From above visualizaion we can say that we  used to make an informed decision to target a category, which is popular among user and not having a lot of apps listed in Google Playstore.
#
#
# ***2. Which category App's have most number of installs?***
#
# * If we compare chart the charts we can see that although the most number of apps present in playstore belongs to categories like Family, Game, Tool, Business, Medical. However, the most installed apps belong to categories like Game, Communication, Tools, Productivity &, Social.
# * Hence we can see that categories where comparatively less number of app are present but they are more popular among users (categories like Communication & Social) can be targeted for future business expansion purpose.
#
# ***3. Percentage of Review Sentiments*** **bold text**
# We get below information through our visualization.
# 1. Approx **64.21%** are Positive reviews
# 2. Approx **21.44%** are Positive reviews
# 3. Approx **14.35%**are Positive reviews
#
# * We can say that most of the users are happy with the quality and Content of the Apps, considering the fact there are 64.30% review are positive.
#
#
# ***4. Which category of Apps from the Content Rating column are found more on playstore ?***
#
# *  From the above plot we can see that **Everyone** category has the **highest** number of apps.
#
# ***5. What portion of the apps in playstore are paid and free?***
# * This information will help business to decide whether they should keep the app free to install and generate revenue from ads and other subscriptions OR should it be a paid app.
#
#
# ***6. What are the top 10 most reviewed App on Play Store app?***
#
# * One important insight that we can see from this chart that there are 3 Apps in the top 10 which are targeted towrds Teens as their audience.
# * From Chart no. 5 we can see that there are total 1036 apps targeted towards Teens as audience, which is much lesser in number if we see "Everyone" category having 7903 Apps, yet 3 of them featured in top 10 reviewed apps.
# * This means there is a lot of potential to grow the business if we can appropriately target Teens as our audience.
#
#
# ***7. Histogram of Subjectivity***
# * It can be seen that maximum number of sentiment subjectivity lies between 0.4 to 0.7. From this we can conclude that maximum number of users give reviews to the applications, according to their experience.
#
# ***8. Do price of the app effects the rating?***
#
# * We found from above visualization that as the Price increasing the ratings recived seems to decrease even below the average rating  in playstore app.
#
# ***9. It would be interesting to see if there is any relationship between Ratings vs Reviews. Does more number of reviews means more ratings?***
#
#
# *   From the above plot, we cannot say that there is a relation, it seems that irrespective of the Reviews, the ratings are majorly between 4 and 5, which we also noticed before.
#
# *   Also it is not correct to assume that rating and reviews have a relationship because reviews can be positive or negative and increase in the number of reviews does not show whether.  the Reviews are Positive or Negative.
#
# ***10. What is the distribution of type of reviews in the dataset?***
#
# *  Majority of the genres have high positive sentiments, when compared to neutral and negative ones.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In this project of analyzing play store applications, we have worked on several parameters which would help Business to do well in launching their apps on the play store.
#
# In the initial phase, we focused more on the problem statements and data cleaning, in order to ensure that we give them the best results out of our analysis.
#
# New Entrepreneur needs to focus more on:
# 1. Developing apps related to the least categories as they are not explored much. Like events and beauty.
# 2. Most of the apps are Free, so focusing on free app is more important.
# 3. Focusing more on content available for Everyone will increase the chances of getting the highest installs.
# 4. They need to focus on updating their apps regularly, so that it will attract more users.
# 5. They need to keep in mind that the sentiments of the user keep varying as they keep using the app, so they should focus more on users needs and features.

# %% [markdown]
# # Special Thanks :
#
#  * I wanted to express my gratitude for giving me this opportunity to enhance my skills in Python through the amazing Project.
#
#  * I would like to show my sincere gratitude to the awesome mentors and my favourite 'ROCHIT JAIN'

# %% [markdown]
# ### ***Hurrah! we have successfully completed your EDA Capstone Project !!!***
